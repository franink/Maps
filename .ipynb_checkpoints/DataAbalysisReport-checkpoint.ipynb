# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
os.chdir('/Users/frankkanayet/Desktop/Maps')
db = pd.read_csv('MapsResultsIntegrity.csv')
db
# Out:
#         State Name  NumberDIstricts  Cluster_Avg_Distance  \
# 0          Alabama                7           60840.42103
# 1          Arizona                9           53998.42873
# 2         Arkansas                4           80936.14729
# 3       California               53           20231.82632
# 4         Colorado                7           45188.78001
# 5      Connecticut                5           22599.03188
# 6          Florida               27           27027.02933
# 7          Georgia               14           42651.09907
# 8           Hawaii                2           96806.97003
# 9            Idaho                2          179234.96520
# 10        Illinois               18           28624.62594
# 11         Indiana                9           44548.08799
# 12            Iowa                4           78683.47842
# 13          Kansas                4           88204.74600
# 14        Kentucky                6           59946.97151
# 15       Louisiana                6           48257.12890
# 16           Maine                2           81529.81809
# 17        Maryland                8           25265.77678
# 18   Massachusetts                9           20307.60335
# 19        Michigan               14           41213.90018
# 20       Minnesota                8           56119.81099
# 21     Mississippi                4           87773.72807
# 22        Missouri                8           52533.53593
# 23        Nebraska                3           93016.11475
# 24          Nevada                4           43147.77710
# 25   New Hampshire                2           50312.34547
# 26      New Jersey               12           15948.90867
# 27      New Mexico                3          114980.61850
# 28        New York               27           20059.05126
# 29  North Carolina               13           42685.35677
# 30            Ohio               16           30713.03778
# 31        Oklahoma                5           75256.79420
# 32          Oregon                5           65550.14482
# 33    Pennsylvania               18           29023.06616
# 34    Rhode Island                2           19585.21986
# 35  South Carolina                7           51960.73113
# 36       Tennessee                9           43088.36373
# 37           Texas               36           43042.12118
# 38            Utah                4           76768.21608
# 39        Virginia               11           37178.95638
# 40      Washington               10           39188.51118
# 41   West Virginia                3           93341.69433
# 42       Wisconsin                8           51529.79803
#
#     District_Avg_Distance  District-Cluster Difference  State  \
# 0             69162.93535                   8322.51432      1
# 1             74140.02983                  20141.60110      4
# 2             86976.05993                   6039.91264      5
# 3             33065.68108                  12833.85476      6
# 4             58745.98835                  13557.20834      8
# 5             26291.51755                   3692.48567      9
# 6             45458.66308                  18431.63375     12
# 7             56391.68703                  13740.58796     13
# 8            102291.48470                   5484.51467     15
# 9            200285.23600                  21050.27080     16
# 10            40897.35432                  12272.72838     17
# 11            57466.51843                  12918.43044     18
# 12            94214.37607                  15530.89765     19
# 13            88266.55466                     61.80866     20
# 14            72367.27952                  12420.30801     21
# 15            60000.94078                  11743.81188     22
# 16            94343.33351                  12813.51542     23
# 17            35304.20320                  10038.42642     24
# 18            29363.63328                   9056.02993     25
# 19            49744.64152                   8530.74134     26
# 20            69524.52354                  13404.71255     27
# 21            99695.91276                  11922.18469     28
# 22            63020.31807                  10486.78214     29
# 23            96921.64346                   3905.52871     31
# 24            78591.20673                  35443.42963     32
# 25            59112.92115                   8800.57568     33
# 26            22373.36346                   6424.45479     34
# 27           136523.51230                  21542.89380     35
# 28            30130.25121                  10071.19995     36
# 29            59235.81910                  16550.46233     37
# 30            45536.52411                  14823.48633     39
# 31            82153.26888                   6896.47468     40
# 32            84846.53577                  19296.39095     41
# 42                    82.638889                    69.097222             15
#
# [43 rows x 21 columns]

# %%
y_names = db.keys()[6:]
y_names
# Out:
# Index([u'Integrity Index', u'Public Access to Information', u'Political Financing', u'Executive Accountability', u'Legislative Accountability', u'Judicial Accountability', u'State Budget Processes', u'State Civil Service Management', u'Procurement', u'Internal Auditing', u'Lobbying Disclosure', u'State Pension Fund Management', u'Ethics Enforcement Agencies', u'State Insurance Commissions', u'Redistricting'], dtype='object')

# %%
X = db[['District-Cluster Difference','NumberDIstricts']]
X = sm.add_constant(X)
for var in y_names:
    Y = db[var]
    model = sm.OLS(Y,X)
    res = model.fit()
    print res.summary()
    fig = plt.figure(figsize=(12,8))
    fig = sm.graphics.plot_partregress_grid(res, fig=fig)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Integrity Index   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     3.968
# Date:                Sun, 24 May 2015   Prob (F-statistic):             0.0268
# Time:                        17:50:15   Log-Likelihood:                -147.29
# No. Observations:                  43   AIC:                             300.6
# Df Residuals:                      40   BIC:                             305.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          74.2333      2.631     28.217      0.000        68.916    79.550
# District-Cluster Difference    -0.0004      0.000     -2.730      0.009        -0.001    -0.000
# NumberDIstricts                 0.1307      0.121      1.081      0.286        -0.114     0.375
# ==============================================================================
# Omnibus:                        1.849   Durbin-Watson:                   2.297
# Prob(Omnibus):                  0.397   Jarque-Bera (JB):                0.993
# Skew:                          -0.319   Prob(JB):                        0.609
# Kurtosis:                       3.382   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     Public Access to Information   R-squared:                       0.084
# Model:                                      OLS   Adj. R-squared:                  0.038
# Method:                           Least Squares   F-statistic:                     1.840
# Date:                          Sun, 24 May 2015   Prob (F-statistic):              0.172
# Time:                                  17:50:16   Log-Likelihood:                -181.18
# No. Observations:                            43   AIC:                             368.4
# Df Residuals:                                40   BIC:                             373.6
# Df Model:                                     2
# Covariance Type:                      nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          66.9859      5.787     11.576      0.000        55.290    78.682
# District-Cluster Difference    -0.0007      0.000     -1.848      0.072        -0.001  6.24e-05
# NumberDIstricts                 0.2061      0.266      0.775      0.443        -0.332     0.744
# ==============================================================================
# Omnibus:                        9.556   Durbin-Watson:                   2.370
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                2.799
# Skew:                          -0.178   Prob(JB):                        0.247
# Kurtosis:                       1.802   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Political Financing   R-squared:                       0.074
# Model:                             OLS   Adj. R-squared:                  0.028
# Method:                  Least Squares   F-statistic:                     1.602
# Date:                 Sun, 24 May 2015   Prob (F-statistic):              0.214
# Time:                         17:50:16   Log-Likelihood:                -166.55
# No. Observations:                   43   AIC:                             339.1
# Df Residuals:                       40   BIC:                             344.4
# Df Model:                            2
# Covariance Type:             nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          73.9403      4.118     17.955      0.000        65.617    82.263
# District-Cluster Difference    -0.0005      0.000     -1.752      0.087        -0.001  6.92e-05
# NumberDIstricts                -0.0205      0.189     -0.108      0.914        -0.403     0.362
# ==============================================================================
# Omnibus:                        1.654   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.437   Jarque-Bera (JB):                1.421
# Skew:                          -0.435   Prob(JB):                        0.491
# Kurtosis:                       2.811   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Executive Accountability   R-squared:                       0.129
# Model:                                  OLS   Adj. R-squared:                  0.085
# Method:                       Least Squares   F-statistic:                     2.958
# Date:                      Sun, 24 May 2015   Prob (F-statistic):             0.0634
# Time:                              17:50:16   Log-Likelihood:                -154.23
# No. Observations:                        43   AIC:                             314.5
# Df Residuals:                            40   BIC:                             319.7
# Df Model:                                 2
# Covariance Type:                  nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          76.1112      3.092     24.617      0.000        69.862    82.360
# District-Cluster Difference    -0.0005      0.000     -2.395      0.021        -0.001 -7.23e-05
# NumberDIstricts                 0.1085      0.142      0.763      0.450        -0.179     0.396
# ==============================================================================
# Omnibus:                        1.983   Durbin-Watson:                   2.464
# Prob(Omnibus):                  0.371   Jarque-Bera (JB):                1.689
# Skew:                          -0.478   Prob(JB):                        0.430
# Kurtosis:                       2.831   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Legislative Accountability   R-squared:                       0.041
# Model:                                    OLS   Adj. R-squared:                 -0.007
# Method:                         Least Squares   F-statistic:                    0.8554
# Date:                        Sun, 24 May 2015   Prob (F-statistic):              0.433
# Time:                                17:50:16   Log-Likelihood:                -156.48
# No. Observations:                          43   AIC:                             319.0
# Df Residuals:                              40   BIC:                             324.2
# Df Model:                                   2
# Covariance Type:                    nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          67.5913      3.258     20.746      0.000        61.007    74.176
# District-Cluster Difference    -0.0002      0.000     -0.951      0.348        -0.001     0.000
# NumberDIstricts                 0.1537      0.150      1.026      0.311        -0.149     0.456
# ==============================================================================
# Omnibus:                        6.642   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                5.806
# Skew:                          -0.623   Prob(JB):                       0.0549
# Kurtosis:                       4.300   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Judicial Accountability   R-squared:                       0.003
# Model:                                 OLS   Adj. R-squared:                 -0.047
# Method:                      Least Squares   F-statistic:                   0.06496
# Date:                     Sun, 24 May 2015   Prob (F-statistic):              0.937
# Time:                             17:50:17   Log-Likelihood:                -160.67
# No. Observations:                       43   AIC:                             327.3
# Df Residuals:                           40   BIC:                             332.6
# Df Model:                                2
# Covariance Type:                 nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          67.5001      3.592     18.794      0.000        60.241    74.759
# District-Cluster Difference  5.318e-05      0.000      0.237      0.814        -0.000     0.001
# NumberDIstricts                -0.0500      0.165     -0.303      0.764        -0.384     0.284
# ==============================================================================
# Omnibus:                        8.898   Durbin-Watson:                   1.554
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.012
# Skew:                          -1.000   Prob(JB):                       0.0182
# Kurtosis:                       3.684   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     State Budget Processes   R-squared:                       0.060
# Model:                                OLS   Adj. R-squared:                  0.013
# Method:                     Least Squares   F-statistic:                     1.268
# Date:                    Sun, 24 May 2015   Prob (F-statistic):              0.292
# Time:                            17:50:17   Log-Likelihood:                -166.96
# No. Observations:                      43   AIC:                             339.9
# Df Residuals:                          40   BIC:                             345.2
# Df Model:                               2
# Covariance Type:                nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          80.8860      4.157     19.456      0.000        72.484    89.288
# District-Cluster Difference    -0.0003      0.000     -1.285      0.206        -0.001     0.000
# NumberDIstricts                -0.1424      0.191     -0.745      0.460        -0.529     0.244
# ==============================================================================
# Omnibus:                        2.937   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.230   Jarque-Bera (JB):                2.764
# Skew:                          -0.582   Prob(JB):                        0.251
# Kurtosis:                       2.566   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     State Civil Service Management   R-squared:                       0.069
# Model:                                        OLS   Adj. R-squared:                  0.023
# Method:                             Least Squares   F-statistic:                     1.488
# Date:                            Sun, 24 May 2015   Prob (F-statistic):              0.238
# Time:                                    17:50:17   Log-Likelihood:                -171.13
# No. Observations:                              43   AIC:                             348.3
# Df Residuals:                                  40   BIC:                             353.5
# Df Model:                                       2
# Covariance Type:                        nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          72.7694      4.581     15.886      0.000        63.512    82.027
# District-Cluster Difference    -0.0005      0.000     -1.724      0.092        -0.001  8.49e-05
# NumberDIstricts                 0.0420      0.211      0.199      0.843        -0.384     0.468
# ==============================================================================
# Omnibus:                       10.592   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.057
# Skew:                          -1.018   Prob(JB):                      0.00655
# Kurtosis:                       4.210   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Procurement   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.044
# Method:                 Least Squares   F-statistic:                    0.1221
# Date:                Sun, 24 May 2015   Prob (F-statistic):              0.885
# Time:                        17:50:17   Log-Likelihood:                -152.57
# No. Observations:                  43   AIC:                             311.1
# Df Residuals:                      40   BIC:                             316.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          82.7822      2.975     27.828      0.000        76.770    88.794
# District-Cluster Difference -4.272e-05      0.000     -0.230      0.819        -0.000     0.000
# NumberDIstricts                -0.0546      0.137     -0.399      0.692        -0.331     0.222
# ==============================================================================
# Omnibus:                        3.602   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.165   Jarque-Bera (JB):                3.396
# Skew:                          -0.644   Prob(JB):                        0.183
# Kurtosis:                       2.512   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Internal Auditing   R-squared:                       0.183
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     4.484
# Date:                Sun, 24 May 2015   Prob (F-statistic):             0.0175
# Time:                        17:50:18   Log-Likelihood:                -152.51
# No. Observations:                  43   AIC:                             311.0
# Df Residuals:                      40   BIC:                             316.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          94.2365      2.971     31.720      0.000        88.232   100.241
# District-Cluster Difference    -0.0005      0.000     -2.833      0.007        -0.001    -0.000
# NumberDIstricts                 0.1872      0.137      1.371      0.178        -0.089     0.463
# ==============================================================================
# Omnibus:                       32.120   Durbin-Watson:                   1.844
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.366
# Skew:                          -1.804   Prob(JB):                     1.19e-21
# Kurtosis:                       9.385   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Lobbying Disclosure   R-squared:                       0.087
# Model:                             OLS   Adj. R-squared:                  0.041
# Method:                  Least Squares   F-statistic:                     1.896
# Date:                 Sun, 24 May 2015   Prob (F-statistic):              0.163
# Time:                         17:50:18   Log-Likelihood:                -171.04
# No. Observations:                   43   AIC:                             348.1
# Df Residuals:                       40   BIC:                             353.4
# Df Model:                            2
# Covariance Type:             nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          74.1088      4.571     16.212      0.000        64.870    83.348
# District-Cluster Difference    -0.0005      0.000     -1.598      0.118        -0.001     0.000
# NumberDIstricts                 0.2800      0.210      1.332      0.190        -0.145     0.705
# ==============================================================================
# Omnibus:                        5.423   Durbin-Watson:                   2.522
# Prob(Omnibus):                  0.066   Jarque-Bera (JB):                2.017
# Skew:                           0.017   Prob(JB):                        0.365
# Kurtosis:                       1.940   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     State Pension Fund Management   R-squared:                       0.061
# Model:                                       OLS   Adj. R-squared:                  0.014
# Method:                            Least Squares   F-statistic:                     1.295
# Date:                           Sun, 24 May 2015   Prob (F-statistic):              0.285
# Time:                                   17:50:18   Log-Likelihood:                -182.25
# No. Observations:                             43   AIC:                             370.5
# Df Residuals:                                 40   BIC:                             375.8
# Df Model:                                      2
# Covariance Type:                       nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          70.2905      5.933     11.848      0.000        58.300    82.281
# District-Cluster Difference    -0.0005      0.000     -1.474      0.148        -0.001     0.000
# NumberDIstricts                 0.2327      0.273      0.853      0.399        -0.319     0.784
# ==============================================================================
# Omnibus:                        1.413   Durbin-Watson:                   1.746
# Prob(Omnibus):                  0.493   Jarque-Bera (JB):                1.361
# Skew:                          -0.397   Prob(JB):                        0.506
# Kurtosis:                       2.640   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Ethics Enforcement Agencies   R-squared:                       0.143
# Model:                                     OLS   Adj. R-squared:                  0.100
# Method:                          Least Squares   F-statistic:                     3.330
# Date:                         Sun, 24 May 2015   Prob (F-statistic):             0.0460
# Time:                                 17:50:19   Log-Likelihood:                -199.71
# No. Observations:                           43   AIC:                             405.4
# Df Residuals:                               40   BIC:                             410.7
# Df Model:                                    2
# Covariance Type:                     nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          67.4625      8.904      7.576      0.000        49.466    85.459
# District-Cluster Difference    -0.0012      0.001     -2.188      0.035        -0.002 -9.29e-05
# NumberDIstricts                 0.6836      0.409      1.670      0.103        -0.144     1.511
# ==============================================================================
# Omnibus:                        6.729   Durbin-Watson:                   2.111
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.402
# Skew:                          -0.945   Prob(JB):                       0.0407
# Kurtosis:                       2.989   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     State Insurance Commissions   R-squared:                       0.106
# Model:                                     OLS   Adj. R-squared:                  0.062
# Method:                          Least Squares   F-statistic:                     2.378
# Date:                         Sun, 24 May 2015   Prob (F-statistic):              0.106
# Time:                                 17:50:19   Log-Likelihood:                -173.92
# No. Observations:                           43   AIC:                             353.8
# Df Residuals:                               40   BIC:                             359.1
# Df Model:                                    2
# Covariance Type:                     nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          75.2450      4.888     15.395      0.000        65.366    85.124
# District-Cluster Difference    -0.0007      0.000     -2.152      0.037        -0.001    -4e-05
# NumberDIstricts                 0.1483      0.225      0.660      0.513        -0.306     0.602
# ==============================================================================
# Omnibus:                        0.678   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.712   Jarque-Bera (JB):                0.770
# Skew:                          -0.257   Prob(JB):                        0.680
# Kurtosis:                       2.592   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Redistricting   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.044
# Method:                 Least Squares   F-statistic:                    0.1227
# Date:                Sun, 24 May 2015   Prob (F-statistic):              0.885
# Time:                        17:50:19   Log-Likelihood:                -201.89
# No. Observations:                  43   AIC:                             409.8
# Df Residuals:                      40   BIC:                             415.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          69.3569      9.367      7.404      0.000        50.425    88.289
# District-Cluster Difference    -0.0003      0.001     -0.492      0.625        -0.001     0.001
# NumberDIstricts                 0.0552      0.431      0.128      0.899        -0.815     0.926
# ==============================================================================
# Omnibus:                        2.348   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.309   Jarque-Bera (JB):                1.933
# Skew:                          -0.381   Prob(JB):                        0.380
# Kurtosis:                       2.294   Cond. No.                     3.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import scipy.stats as stats
X = db['District-Cluster Difference']
res = {}
for var in y_names:
    Y = db[var]
    tmp = stats.spearmanr(X,Y)
    res[var] = tmp
res_DF = pd.DataFrame(res, index=['rho','p-val'])
res_DF.transpose()
# Out:
#                                      rho     p-val
# Ethics Enforcement Agencies    -0.347905  0.022250
# Executive Accountability       -0.383886  0.011043
# Integrity Index                -0.409846  0.006345
# Internal Auditing              -0.075759  0.629209
# Judicial Accountability        -0.059499  0.704689
# Legislative Accountability     -0.251482  0.103791
# Lobbying Disclosure            -0.199600  0.199403
# Political Financing            -0.260948  0.090998
# Procurement                    -0.129296  0.408610
# Public Access to Information   -0.317213  0.038202
# Redistricting                  -0.049640  0.751915
# State Budget Processes         -0.197697  0.203811
# State Civil Service Management -0.338506  0.026397
# State Insurance Commissions    -0.311875  0.041758
# State Pension Fund Management  -0.209906  0.176697

# %%
X = db[['Cluster_Avg_Distance', 'District_Avg_Distance', 'District-Cluster Difference','NumberDIstricts']]
X = sm.add_constant(X)
for var in y_names:
    Y = db[var]
    model = sm.OLS(Y,X)
    res = model.fit()
    print res.summary()
    fig = plt.figure(figsize=(12,12))
    fig = sm.graphics.plot_partregress_grid(res, fig=fig)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Integrity Index   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     2.677
# Date:                Sun, 24 May 2015   Prob (F-statistic):             0.0604
# Time:                        17:50:26   Log-Likelihood:                -147.15
# No. Observations:                  43   AIC:                             302.3
# Df Residuals:                      39   BIC:                             309.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          75.5851      3.809     19.842      0.000        67.880    83.290
# Cluster_Avg_Distance            0.0001    6.9e-05      1.871      0.069     -1.05e-05     0.000
# District_Avg_Distance          -0.0002   5.54e-05     -2.729      0.009        -0.000 -3.91e-05
# District-Cluster Difference    -0.0003      0.000     -2.397      0.021        -0.001 -4.38e-05
# NumberDIstricts                 0.0946      0.142      0.665      0.510        -0.193     0.382
# ==============================================================================
# Omnibus:                        2.245   Durbin-Watson:                   2.265
# Prob(Omnibus):                  0.325   Jarque-Bera (JB):                1.335
# Skew:                          -0.390   Prob(JB):                        0.513
# Kurtosis:                       3.371   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     Public Access to Information   R-squared:                       0.088
# Model:                                      OLS   Adj. R-squared:                  0.018
# Method:                           Least Squares   F-statistic:                     1.256
# Date:                          Sun, 24 May 2015   Prob (F-statistic):              0.303
# Time:                                  17:50:26   Log-Likelihood:                -181.09
# No. Observations:                            43   AIC:                             370.2
# Df Residuals:                                39   BIC:                             377.2
# Df Model:                                     3
# Covariance Type:                      nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          64.5343      8.388      7.694      0.000        47.568    81.500
# Cluster_Avg_Distance            0.0003      0.000      1.709      0.095     -4.76e-05     0.001
# District_Avg_Distance          -0.0002      0.000     -1.801      0.079        -0.000   2.7e-05
# District-Cluster Difference    -0.0005      0.000     -1.862      0.070        -0.001  4.13e-05
# NumberDIstricts                 0.2716      0.313      0.867      0.391        -0.362     0.905
# ==============================================================================
# Omnibus:                        9.252   Durbin-Watson:                   2.408
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                2.638
# Skew:                          -0.106   Prob(JB):                        0.267
# Kurtosis:                       1.805   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Political Financing   R-squared:                       0.078
# Model:                             OLS   Adj. R-squared:                  0.007
# Method:                  Least Squares   F-statistic:                     1.104
# Date:                 Sun, 24 May 2015   Prob (F-statistic):              0.359
# Time:                         17:50:27   Log-Likelihood:                -166.46
# No. Observations:                   43   AIC:                             340.9
# Df Residuals:                       39   BIC:                             348.0
# Df Model:                            3
# Covariance Type:             nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          75.7307      5.968     12.689      0.000        63.658    87.803
# Cluster_Avg_Distance            0.0001      0.000      1.139      0.262     -9.56e-05     0.000
# District_Avg_Distance          -0.0002   8.68e-05     -1.756      0.087        -0.000  2.31e-05
# District-Cluster Difference    -0.0003      0.000     -1.504      0.141        -0.001   9.5e-05
# NumberDIstricts                -0.0684      0.223     -0.307      0.761        -0.519     0.382
# ==============================================================================
# Omnibus:                        1.727   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.422   Jarque-Bera (JB):                1.519
# Skew:                          -0.447   Prob(JB):                        0.468
# Kurtosis:                       2.779   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Executive Accountability   R-squared:                       0.197
# Model:                                  OLS   Adj. R-squared:                  0.135
# Method:                       Least Squares   F-statistic:                     3.184
# Date:                      Sun, 24 May 2015   Prob (F-statistic):             0.0343
# Time:                              17:50:27   Log-Likelihood:                -152.49
# No. Observations:                        43   AIC:                             313.0
# Df Residuals:                            39   BIC:                             320.0
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          81.7242      4.312     18.951      0.000        73.001    90.447
# Cluster_Avg_Distance          6.93e-05   7.81e-05      0.887      0.380     -8.87e-05     0.000
# District_Avg_Distance          -0.0002   6.27e-05     -2.568      0.014        -0.000 -3.42e-05
# District-Cluster Difference    -0.0002      0.000     -1.740      0.090        -0.000  3.73e-05
# NumberDIstricts                -0.0414      0.161     -0.257      0.798        -0.367     0.284
# ==============================================================================
# Omnibus:                        4.566   Durbin-Watson:                   2.253
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                3.788
# Skew:                          -0.724   Prob(JB):                        0.150
# Kurtosis:                       3.127   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Legislative Accountability   R-squared:                       0.090
# Model:                                    OLS   Adj. R-squared:                  0.020
# Method:                         Least Squares   F-statistic:                     1.290
# Date:                        Sun, 24 May 2015   Prob (F-statistic):              0.291
# Time:                                17:50:27   Log-Likelihood:                -155.35
# No. Observations:                          43   AIC:                             318.7
# Df Residuals:                              39   BIC:                             325.7
# Df Model:                                   3
# Covariance Type:                    nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          72.3933      4.609     15.706      0.000        63.070    81.716
# Cluster_Avg_Distance        -8.137e-06   8.35e-05     -0.097      0.923        -0.000     0.000
# District_Avg_Distance       -7.034e-05    6.7e-05     -1.050      0.300        -0.000  6.52e-05
# District-Cluster Difference  -6.22e-05      0.000     -0.440      0.663        -0.000     0.000
# NumberDIstricts                 0.0255      0.172      0.148      0.883        -0.323     0.374
# ==============================================================================
# Omnibus:                        6.473   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                5.333
# Skew:                          -0.670   Prob(JB):                       0.0695
# Kurtosis:                       4.087   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Judicial Accountability   R-squared:                       0.003
# Model:                                 OLS   Adj. R-squared:                 -0.073
# Method:                      Least Squares   F-statistic:                   0.04508
# Date:                     Sun, 24 May 2015   Prob (F-statistic):              0.987
# Time:                             17:50:28   Log-Likelihood:                -160.67
# No. Observations:                       43   AIC:                             329.3
# Df Residuals:                           39   BIC:                             336.4
# Df Model:                                3
# Covariance Type:                 nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          67.1543      5.216     12.874      0.000        56.603    77.705
# Cluster_Avg_Distance         -1.25e-05   9.45e-05     -0.132      0.895        -0.000     0.000
# District_Avg_Distance        1.815e-05   7.58e-05      0.239      0.812        -0.000     0.000
# District-Cluster Difference  3.065e-05      0.000      0.191      0.849        -0.000     0.000
# NumberDIstricts                -0.0408      0.195     -0.209      0.835        -0.435     0.353
# ==============================================================================
# Omnibus:                        8.725   Durbin-Watson:                   1.559
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                7.810
# Skew:                          -0.988   Prob(JB):                       0.0201
# Kurtosis:                       3.673   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     State Budget Processes   R-squared:                       0.073
# Model:                                OLS   Adj. R-squared:                  0.002
# Method:                     Least Squares   F-statistic:                     1.022
# Date:                    Sun, 24 May 2015   Prob (F-statistic):              0.394
# Time:                            17:50:28   Log-Likelihood:                -166.66
# No. Observations:                      43   AIC:                             341.3
# Df Residuals:                          39   BIC:                             348.4
# Df Model:                               3
# Covariance Type:                nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          77.6786      5.996     12.955      0.000        65.550    89.807
# Cluster_Avg_Distance            0.0002      0.000      1.470      0.150        -6e-05     0.000
# District_Avg_Distance          -0.0001   8.72e-05     -1.230      0.226        -0.000  6.91e-05
# District-Cluster Difference    -0.0003      0.000     -1.451      0.155        -0.001     0.000
# NumberDIstricts                -0.0568      0.224     -0.254      0.801        -0.510     0.396
# ==============================================================================
# Omnibus:                        2.787   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.248   Jarque-Bera (JB):                2.602
# Skew:                          -0.574   Prob(JB):                        0.272
# Kurtosis:                       2.634   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     State Civil Service Management   R-squared:                       0.091
# Model:                                        OLS   Adj. R-squared:                  0.022
# Method:                             Least Squares   F-statistic:                     1.309
# Date:                            Sun, 24 May 2015   Prob (F-statistic):              0.285
# Time:                                    17:50:29   Log-Likelihood:                -170.61
# No. Observations:                              43   AIC:                             349.2
# Df Residuals:                                  39   BIC:                             356.3
# Df Model:                                       3
# Covariance Type:                        nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          77.3760      6.574     11.771      0.000        64.080    90.672
# Cluster_Avg_Distance         9.475e-05      0.000      0.796      0.431        -0.000     0.000
# District_Avg_Distance          -0.0002   9.56e-05     -1.779      0.083        -0.000  2.33e-05
# District-Cluster Difference    -0.0003      0.000     -1.313      0.197        -0.001     0.000
# NumberDIstricts                -0.0811      0.245     -0.330      0.743        -0.578     0.415
# ==============================================================================
# Omnibus:                       13.332   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.307
# Skew:                          -1.135   Prob(JB):                     0.000782
# Kurtosis:                       4.684   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Procurement   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.068
# Method:                 Least Squares   F-statistic:                    0.1144
# Date:                Sun, 24 May 2015   Prob (F-statistic):              0.951
# Time:                        17:50:29   Log-Likelihood:                -152.51
# No. Observations:                  43   AIC:                             313.0
# Df Residuals:                      39   BIC:                             320.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          81.7814      4.315     18.952      0.000        73.053    90.510
# Cluster_Avg_Distance         2.937e-05   7.82e-05      0.376      0.709        -0.000     0.000
# District_Avg_Distance       -1.302e-05   6.27e-05     -0.207      0.837        -0.000     0.000
# District-Cluster Difference -4.239e-05      0.000     -0.320      0.751        -0.000     0.000
# NumberDIstricts                -0.0279      0.161     -0.173      0.863        -0.354     0.298
# ==============================================================================
# Omnibus:                        3.624   Durbin-Watson:                   1.796
# Prob(Omnibus):                  0.163   Jarque-Bera (JB):                3.351
# Skew:                          -0.621   Prob(JB):                        0.187
# Kurtosis:                       2.429   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Internal Auditing   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.247
# Method:                 Least Squares   F-statistic:                     5.593
# Date:                Sun, 24 May 2015   Prob (F-statistic):            0.00274
# Time:                        17:50:30   Log-Likelihood:                -149.17
# No. Observations:                  43   AIC:                             306.3
# Df Residuals:                      39   BIC:                             313.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          86.9036      3.992     21.767      0.000        78.828    94.979
# Cluster_Avg_Distance            0.0003   7.23e-05      3.955      0.000         0.000     0.000
# District_Avg_Distance          -0.0002    5.8e-05     -2.863      0.007        -0.000 -4.88e-05
# District-Cluster Difference    -0.0005      0.000     -3.691      0.001        -0.001    -0.000
# NumberDIstricts                 0.3831      0.149      2.570      0.014         0.082     0.685
# ==============================================================================
# Omnibus:                       25.322   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.631
# Skew:                          -1.525   Prob(JB):                     1.37e-12
# Kurtosis:                       7.603   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Lobbying Disclosure   R-squared:                       0.087
# Model:                             OLS   Adj. R-squared:                  0.017
# Method:                  Least Squares   F-statistic:                     1.241
# Date:                 Sun, 24 May 2015   Prob (F-statistic):              0.308
# Time:                         17:50:30   Log-Likelihood:                -171.03
# No. Observations:                   43   AIC:                             350.1
# Df Residuals:                       39   BIC:                             357.1
# Df Model:                            3
# Covariance Type:             nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          74.8537      6.638     11.277      0.000        61.427    88.280
# Cluster_Avg_Distance            0.0001      0.000      1.171      0.249        -0.000     0.000
# District_Avg_Distance          -0.0002   9.65e-05     -1.585      0.121        -0.000  4.23e-05
# District-Cluster Difference    -0.0003      0.000     -1.442      0.157        -0.001     0.000
# NumberDIstricts                 0.2601      0.248      1.049      0.301        -0.241     0.761
# ==============================================================================
# Omnibus:                        5.286   Durbin-Watson:                   2.525
# Prob(Omnibus):                  0.071   Jarque-Bera (JB):                1.993
# Skew:                           0.018   Prob(JB):                        0.369
# Kurtosis:                       1.946   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     State Pension Fund Management   R-squared:                       0.097
# Model:                                       OLS   Adj. R-squared:                  0.028
# Method:                            Least Squares   F-statistic:                     1.402
# Date:                           Sun, 24 May 2015   Prob (F-statistic):              0.257
# Time:                                   17:50:30   Log-Likelihood:                -181.40
# No. Observations:                             43   AIC:                             370.8
# Df Residuals:                                 39   BIC:                             377.8
# Df Model:                                      3
# Covariance Type:                       nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          77.8985      8.448      9.221      0.000        60.810    94.987
# Cluster_Avg_Distance         6.698e-05      0.000      0.438      0.664        -0.000     0.000
# District_Avg_Distance          -0.0002      0.000     -1.558      0.127        -0.000  5.71e-05
# District-Cluster Difference    -0.0003      0.000     -0.996      0.325        -0.001     0.000
# NumberDIstricts                 0.0294      0.315      0.093      0.926        -0.609     0.667
# ==============================================================================
# Omnibus:                        1.431   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.489   Jarque-Bera (JB):                1.328
# Skew:                          -0.405   Prob(JB):                        0.515
# Kurtosis:                       2.708   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Ethics Enforcement Agencies   R-squared:                       0.181
# Model:                                     OLS   Adj. R-squared:                  0.118
# Method:                          Least Squares   F-statistic:                     2.877
# Date:                         Sun, 24 May 2015   Prob (F-statistic):             0.0483
# Time:                                 17:50:31   Log-Likelihood:                -198.73
# No. Observations:                           43   AIC:                             405.5
# Df Residuals:                               39   BIC:                             412.5
# Df Model:                                    3
# Covariance Type:                     nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          79.7313     12.640      6.308      0.000        54.164   105.299
# Cluster_Avg_Distance            0.0002      0.000      0.961      0.342        -0.000     0.001
# District_Avg_Distance          -0.0004      0.000     -2.288      0.028        -0.001 -4.88e-05
# District-Cluster Difference    -0.0006      0.000     -1.652      0.107        -0.001     0.000
# NumberDIstricts                 0.3559      0.472      0.754      0.455        -0.599     1.311
# ==============================================================================
# Omnibus:                        6.808   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                5.990
# Skew:                          -0.902   Prob(JB):                       0.0500
# Kurtosis:                       3.297   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     State Insurance Commissions   R-squared:                       0.174
# Model:                                     OLS   Adj. R-squared:                  0.110
# Method:                          Least Squares   F-statistic:                     2.735
# Date:                         Sun, 24 May 2015   Prob (F-statistic):             0.0566
# Time:                                 17:50:31   Log-Likelihood:                -172.23
# No. Observations:                           43   AIC:                             352.5
# Df Residuals:                               39   BIC:                             359.5
# Df Model:                                    3
# Covariance Type:                     nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          83.9823      6.826     12.303      0.000        70.175    97.790
# Cluster_Avg_Distance         8.684e-05      0.000      0.702      0.487        -0.000     0.000
# District_Avg_Distance          -0.0002   9.92e-05     -2.314      0.026        -0.000 -2.89e-05
# District-Cluster Difference    -0.0003      0.000     -1.511      0.139        -0.001     0.000
# NumberDIstricts                -0.0851      0.255     -0.334      0.740        -0.601     0.430
# ==============================================================================
# Omnibus:                        1.002   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.606   Jarque-Bera (JB):                0.685
# Skew:                          -0.309   Prob(JB):                        0.710
# Kurtosis:                       2.967   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Redistricting   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                 -0.022
# Method:                 Least Squares   F-statistic:                    0.6947
# Date:                Sun, 24 May 2015   Prob (F-statistic):              0.561
# Time:                        17:50:32   Log-Likelihood:                -200.91
# No. Observations:                  43   AIC:                             409.8
# Df Residuals:                      39   BIC:                             416.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          56.4488     13.297      4.245      0.000        29.552    83.345
# Cluster_Avg_Distance            0.0003      0.000      1.209      0.234        -0.000     0.001
# District_Avg_Distance       -8.013e-05      0.000     -0.414      0.681        -0.000     0.000
# District-Cluster Difference    -0.0004      0.000     -0.910      0.369        -0.001     0.000
# NumberDIstricts                 0.4000      0.497      0.806      0.425        -0.604     1.404
# ==============================================================================
# Omnibus:                        2.132   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.344   Jarque-Bera (JB):                1.795
# Skew:                          -0.364   Prob(JB):                        0.408
# Kurtosis:                       2.313   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Our clustering Spearman correlations

# %%
X = db['Cluster_Avg_Distance']
res = {}
for var in y_names:
    Y = db[var]
    tmp = stats.spearmanr(X,Y)
    res[var] = tmp
res_DF = pd.DataFrame(res, index=['rho','p-val'])
res_DF.transpose()
# Out:
#                                      rho     p-val
# Ethics Enforcement Agencies    -0.165414  0.289122
# Executive Accountability       -0.232793  0.133027
# Integrity Index                -0.151314  0.332752
# Internal Auditing               0.255507  0.098194
# Judicial Accountability         0.062217  0.691850
# Legislative Accountability     -0.149605  0.338303
# Lobbying Disclosure            -0.220745  0.154885
# Political Financing            -0.144216  0.356185
# Procurement                     0.077577  0.620977
# Public Access to Information   -0.156038  0.317701
# Redistricting                   0.046219  0.768524
# State Budget Processes          0.207967  0.180822
# State Civil Service Management -0.064938  0.679084
# State Insurance Commissions    -0.241420  0.118851
# State Pension Fund Management  -0.176835  0.256635

# %% [markdown]
# ## Actual districting Spearman correlationa

# %%
X = db['District_Avg_Distance']
res = {}
for var in y_names:
    Y = db[var]
    tmp = stats.spearmanr(X,Y)
    res[var] = tmp
res_DF = pd.DataFrame(res, index=['rho','p-val'])
res_DF.transpose()
# Out:
#                                      rho     p-val
# Ethics Enforcement Agencies    -0.181131  0.245072
# Executive Accountability       -0.297957  0.052307
# Integrity Index                -0.192842  0.215362
# Internal Auditing               0.226066  0.144930
# Judicial Accountability         0.059650  0.703974
# Legislative Accountability     -0.153683  0.325147
# Lobbying Disclosure            -0.231771  0.134787
# Political Financing            -0.163546  0.294677
# Procurement                     0.076670  0.625079
# Public Access to Information   -0.165105  0.290035
# Redistricting                   0.086357  0.581891
# State Budget Processes          0.094544  0.546474
# State Civil Service Management -0.153358  0.326185
# State Insurance Commissions    -0.304248  0.047301
# State Pension Fund Management  -0.202960  0.191786

# %% [markdown]
# ##Difference vs real districting

# %%
X = db[['District-Cluster Difference','District_Avg_Distance', 'NumberDIstricts']]
X = sm.add_constant(X)
Y = db['Integrity Index']
model = sm.OLS(Y,X)
res = model.fit()
print res.summary()
fig = plt.figure(figsize=(12,12))
fig = sm.graphics.plot_partregress_grid(res, fig=fig)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Integrity Index   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     2.677
# Date:                Sun, 24 May 2015   Prob (F-statistic):             0.0604
# Time:                        17:52:00   Log-Likelihood:                -147.15
# No. Observations:                  43   AIC:                             302.3
# Df Residuals:                      39   BIC:                             309.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# const                          75.5851      3.809     19.842      0.000        67.880    83.290
# District-Cluster Difference    -0.0004      0.000     -2.227      0.032        -0.001 -3.75e-05
# District_Avg_Distance       -2.209e-05   4.46e-05     -0.495      0.623        -0.000  6.82e-05
# NumberDIstricts                 0.0946      0.142      0.665      0.510        -0.193     0.382
# ==============================================================================
# Omnibus:                        2.245   Durbin-Watson:                   2.265
# Prob(Omnibus):                  0.325   Jarque-Bera (JB):                1.335
# Skew:                          -0.390   Prob(JB):                        0.513
# Kurtosis:                       3.371   Cond. No.                     2.48e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.48e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
